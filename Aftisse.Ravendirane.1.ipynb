# %% [markdown]
# <h1 style="padding:8px; margin:0px -20px; color:#FFF; background:#06D">Coffee Data Analysis</h1>
#
# - AFTISSE Melissa (<aftisse.melissa@etu.u-bordeaux.fr>)
# - RAVENDIRANE Gayathiri (<gayathiri.ravendirane@etu.u-bordeaux.fr>)
#
# Version : 1.0

# %%
# IMPORTS
import numpy as np
import seaborn as sns
import pandas as pd 
import matplotlib.pyplot as plt
from ipywidgets import interact, interact_manual

# %% [markdown]
# <h2 style="padding:10px; color:#FFF; background:#06D">Importation du jeu de données</h2>

# %% [markdown]
# <div style="padding:8px; margin:0px -20px; color:#FFF; background:#06D; text-align:right">● ● ● </div>
